# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("Student Mental health.csv")
df
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
#Histplot
#Scatterplot
#Kdeplot
#lineplot
#pairplot
#barplt
#heatmap
#countplot
#Boxplot
#pairplot

# %%
df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
df.describe().T
# Out:
#      count   mean      std   min   25%   50%   75%   max
# Age  100.0  20.53  2.49628  18.0  18.0  19.0  23.0  24.0

# %%
df.dtypes
# Out:
# Timestamp                                               object
# Choose your gender                                      object
# Age                                                    float64
# What is your course?                                    object
# Your current year of Study                              object
# What is your CGPA?                              datetime64[ns]
# Marital status                                          object
# Do you have Depression?                                 object
# Do you have Anxiety?                                    object
# Do you have Panic attack?                               object
# Did you seek any specialist for a treatment?            object
# dtype: object

# %%
df["What is your CGPA?"] = pd.to_datetime(df["What is your CGPA?"],errors='coerce')
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_5624\1451145681.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["What is your CGPA?"] = pd.to_datetime(df["What is your CGPA?"],errors='coerce')

# %%
df.shape
# Out:
# (101, 11)

# %%
df["Age"].value_counts().sum()
# Out:
# 100

# %%
df.isnull().sum()
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             1
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
#Finding out the column number whose age is unknown to us
df["Age"].isnull().sum()
df[df["Age"].isna()]
# Out:
# 1

# %%
df[df['Age'].isna()]
# Out:
#          Timestamp Choose your gender  Age What is your course?  \
# 43  8/7/2020 15:07               Male  NaN                  BIT
#
#    Your current year of Study What is your CGPA? Marital status  \
# 43                     year 1           0 - 1.99             No
#
#    Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 43                      No                   No                        No
#
#    Did you seek any specialist for a treatment?
# 43                                           No

# %%
df["Age"][df["Age"].isna()==True]
# Out:
# 43   NaN
# Name: Age, dtype: float64

# %%
#Find The Age Group From 40 to 50 Year 
x = df["Age"].value_counts()
x
# Out:
# Age
# 18.0    32
# 24.0    23
# 19.0    21
# 23.0    13
# 20.0     6
# 21.0     3
# 22.0     2
# Name: count, dtype: int64

# %%
df.loc[40:50]
# Out:
#          Timestamp Choose your gender   Age What is your course?  \
# 40  8/7/2020 14:57             Female  24.0                  BIT
# 41  8/7/2020 14:57             Female  22.0          Engineering
# 42  8/7/2020 14:58             Female  20.0           Usuluddin
# 43  8/7/2020 15:07               Male   NaN                  BIT
# 44  8/7/2020 15:08               Male  23.0                TAASL
# 45  8/7/2020 15:09               Male  18.0                  BCS
# 46  8/7/2020 15:12             Female  19.0          Engineering
# 47  8/7/2020 15:14             Female  18.0               Engine
# 48  8/7/2020 15:14               Male  24.0                  BCS
# 49  8/7/2020 15:18             Female  24.0                  BCS
# 50  8/7/2020 15:27             Female  23.0                  ALA
#
#    Your current year of Study What is your CGPA? Marital status  \
# 40                     Year 3        3.00 - 3.49             No
# ...

# %%
df["Age"][df["Age"]>=20]
df
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
df.loc[40:45]
# Out:
#          Timestamp Choose your gender   Age What is your course?  \
# 40  8/7/2020 14:57             Female  24.0                  BIT
# 41  8/7/2020 14:57             Female  22.0          Engineering
# 42  8/7/2020 14:58             Female  20.0           Usuluddin
# 43  8/7/2020 15:07               Male   NaN                  BIT
# 44  8/7/2020 15:08               Male  23.0                TAASL
# 45  8/7/2020 15:09               Male  18.0                  BCS
#
#    Your current year of Study What is your CGPA? Marital status  \
# 40                     Year 3        3.00 - 3.49             No
# 41                     year 4        3.50 - 4.00             No
# 42                     year 2        3.00 - 3.49             No
# 43                     year 1           0 - 1.99             No
# 44                     year 2        3.50 - 4.00             No
# 45                     year 1        3.50 - 4.00             No
#
# ...

# %%
#Count the course which are opted by most of the student 
df["What is your course?"].value_counts().head()
# Out:
# What is your course?
# BCS                   18
# Engineering           17
# BIT                   10
# Biomedical science     4
# KOE                    4
# Name: count, dtype: int64

# %%
#Count number of Male or Female 
x = df["Choose your gender"].value_counts()
x
# Out:
# Choose your gender
# Female    75
# Male      26
# Name: count, dtype: int64

# %%
df.groupby()[].mean()
# Out:
# 56.25

# %%
#Find the Mean age of Female And Male 
df.groupby("Choose your gender")["Age"].mean()
# Out:
# Choose your gender
# Female    20.533333
# Male      20.520000
# Name: Age, dtype: float64

# %%
#Find the number of Student of who are married or not married respectively 
df["Marital status"].value_counts()
# Out:
# Marital status
# No     85
# Yes    16
# Name: count, dtype: int64

# %%
#Percentage of student facing Depression 
df["Do you have Depression?"].value_counts()/len(df)*100
# Out:
# Do you have Depression?
# No     65.346535
# Yes    34.653465
# Name: count, dtype: float64

# %%
x = len(df)
x
# Out:
# 101

# %%
#Percentage of Facing Anxiety
df["Do you have Anxiety?"].value_counts()/x*100
# Out:
# Do you have Anxiety?
# No     66.336634
# Yes    33.663366
# Name: count, dtype: float64

# %%
#Percentage of Student of Panic Attack 
df["Do you have Panic attack?"].value_counts()/len(df)*100
# Out:
# Do you have Panic attack?
# No     67.326733
# Yes    32.673267
# Name: count, dtype: float64

# %%
sns.countplot(x=df["Choose your gender"])
plt.show()

# %%
#plt.figure(figsize=(15,10))
sns.countplot(x=df["Marital status"], palette='viridis')
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_5624\3421221475.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["Marital status"], palette='viridis')

# %%
#plt.figure(figsize=(15,10))
sns.boxplot(df["Your current year of Study"])
plt.show()

# %%
df["Your current year of Study"].value_counts()/100*100
# Out:
# Your current year of Study
# year 1    41.0
# Year 3    19.0
# Year 2    16.0
# year 2    10.0
# year 4     8.0
# year 3     5.0
# Year 1     2.0
# Name: count, dtype: float64

# %%
sns.boxplot(x=df["What is your CGPA?"])
plt.show()

# %%
sns.kdeplot(df["Age"], shade=True)
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_27780\3256569379.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["Age"], shade=True)

# %%
sns.histplot(df["What is your CGPA?"])
plt.show()

# %%
sns.histplot(df["Your current year of Study"])
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.barplot(df["What is your course?"])
plt.show()

# %%
sns.lineplot(x=df["Do you have Depression?"], y=df["Age"], data=df, hue="Choose your gender")
plt.show()

# %%
sns.lineplot(x=df["Age"], y=df["What is your CGPA?"], data=df, hue="Choose your gender")
plt.legend(loc=1)
plt.show()

# %%
sns.histplot(df)
plt.show()

# %%
sns.boxplot(x=df["Choose your gender"], y=df["What is your CGPA?"], data=df)
plt.show()

# %%
sns.heatmap(df["Choose your gender"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 sns.heatmap(df["Choose your gender"])
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
# ...
